# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('car details v4.csv')

# %%
df.shape
# Out:
# (2059, 20)

# %%
df.sample(1)
# Out:
#               Make      Model    Price  Year  Kilometer Fuel Type  \
# 158  Mercedes-Benz  GLE 250 d  4550000  2017      34000    Diesel
#
#     Transmission     Location   Color  Owner Seller Type   Engine  \
# 158    Automatic  Navi Mumbai  Silver  First  Individual  2143 cc
#
#               Max Power         Max Torque Drivetrain  Length   Width  Height  \
# 158  201 bhp @ 3800 rpm  500 Nm @ 1600 rpm        AWD  4819.0  2141.0  1796.0
#
#      Seating Capacity  Fuel Tank Capacity
# 158               5.0                93.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                2059 non-null   object
#  1   Model               2059 non-null   object
#  2   Price               2059 non-null   int64
#  3   Year                2059 non-null   int64
#  4   Kilometer           2059 non-null   int64
#  5   Fuel Type           2059 non-null   object
#  6   Transmission        2059 non-null   object
#  7   Location            2059 non-null   object
#  8   Color               2059 non-null   object
#  9   Owner               2059 non-null   object
#  10  Seller Type         2059 non-null   object
#  11  Engine              1979 non-null   object
#  12  Max Power           1979 non-null   object
#  13  Max Torque          1979 non-null   object
#  14  Drivetrain          1923 non-null   object
# ...

# %%
df.isnull().sum()/len(df) * 100
# Out:
# Make                  0.000000
# Model                 0.000000
# Price                 0.000000
# Year                  0.000000
# Kilometer             0.000000
# Fuel Type             0.000000
# Transmission          0.000000
# Location              0.000000
# Color                 0.000000
# Owner                 0.000000
# Seller Type           0.000000
# Engine                3.885381
# Max Power             3.885381
# Max Torque            3.885381
# Drivetrain            6.605148
# Length                3.108305
# Width                 3.108305
# Height                3.108305
# Seating Capacity      3.108305
# Fuel Tank Capacity    5.488101
# dtype: float64

# %%
df.describe()
# Out:
#               Price         Year     Kilometer       Length        Width  \
# count  2.059000e+03  2059.000000  2.059000e+03  1995.000000  1995.000000
# mean   1.702992e+06  2016.425449  5.422471e+04  4280.860652  1767.991980
# std    2.419881e+06     3.363564  5.736172e+04   442.458507   135.265825
# min    4.900000e+04  1988.000000  0.000000e+00  3099.000000  1475.000000
# 25%    4.849990e+05  2014.000000  2.900000e+04  3985.000000  1695.000000
# 50%    8.250000e+05  2017.000000  5.000000e+04  4370.000000  1770.000000
# 75%    1.925000e+06  2019.000000  7.200000e+04  4629.000000  1831.500000
# max    3.500000e+07  2022.000000  2.000000e+06  5569.000000  2220.000000
#
#             Height  Seating Capacity  Fuel Tank Capacity
# count  1995.000000       1995.000000         1946.000000
# mean   1591.735338          5.306266           52.002210
# std     136.073956          0.822170           15.110198
# min    1165.000000          2.000000           15.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # EDA

# %%
numerical_df = df.select_dtypes(include='number')
numerical_df.corr()['Price']
# Out:
# Price                 1.000000
# Year                  0.311400
# Kilometer            -0.150825
# Length                0.556741
# Width                 0.563996
# Height                0.075080
# Seating Capacity     -0.038524
# Fuel Tank Capacity    0.584631
# Name: Price, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats


# Extract the column
data = df['Price']

# Create the figure and axes
fig, axes = plt.subplots(1, 4, figsize=(24, 6))

# KDE plot
sns.kdeplot(data, ax=axes[0])
axes[0].set_title('KDE Plot')

# Boxplot
sns.boxplot(data, ax=axes[1])
axes[1].set_title('Boxplot')

# QQ plot
stats.probplot(data, dist="norm", plot=axes[2])
axes[2].get_lines()[1].set_color('r')
axes[2].set_title('QQ Plot')

# Distplot
sns.histplot(data, kde=True, ax=axes[3])
axes[3].set_title('Distplot')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Extract the column
data = df['Year']
# Create the figure and axes
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
# KDE plot
sns.kdeplot(data, ax=axes[0])
axes[0].set_title('KDE Plot')
# Boxplot
sns.boxplot(data, ax=axes[1])
axes[1].set_title('Boxplot')
# QQ plot
stats.probplot(data, dist="norm", plot=axes[2])
axes[2].get_lines()[1].set_color('r')
axes[2].set_title('QQ Plot')
# Distplot
sns.histplot(data, kde=True, ax=axes[3])
axes[3].set_title('Distplot')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Extract the column
data = df['Kilometer']
# Create the figure and axes
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
# KDE plot
sns.kdeplot(data, ax=axes[0])
axes[0].set_title('KDE Plot')
# Boxplot
sns.boxplot(data, ax=axes[1])
axes[1].set_title('Boxplot')
# QQ plot
stats.probplot(data, dist="norm", plot=axes[2])
axes[2].get_lines()[1].set_color('r')
axes[2].set_title('QQ Plot')
# Distplot
sns.histplot(data, kde=True, ax=axes[3])
axes[3].set_title('Distplot')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Extract the column
data = df['Length']
# Create the figure and axes
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
# KDE plot
sns.kdeplot(data, ax=axes[0])
axes[0].set_title('KDE Plot')
# Boxplot
sns.boxplot(data, ax=axes[1])
axes[1].set_title('Boxplot')
# QQ plot
stats.probplot(data, dist="norm", plot=axes[2])
axes[2].get_lines()[1].set_color('r')
axes[2].set_title('QQ Plot')
# Distplot
sns.histplot(data, kde=True, ax=axes[3])
axes[3].set_title('Distplot')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
data = df['Width']
# Create the figure and axes
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
# KDE plot
sns.kdeplot(data, ax=axes[0])
axes[0].set_title('KDE Plot')
# Boxplot
sns.boxplot(data, ax=axes[1])
axes[1].set_title('Boxplot')
# QQ plot
stats.probplot(data, dist="norm", plot=axes[2])
axes[2].get_lines()[1].set_color('r')
axes[2].set_title('QQ Plot')
# Distplot
sns.histplot(data, kde=True, ax=axes[3])
axes[3].set_title('Distplot')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
data = df['Height']
# Create the figure and axes
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
# KDE plot
sns.kdeplot(data, ax=axes[0])
axes[0].set_title('KDE Plot')
# Boxplot
sns.boxplot(data, ax=axes[1])
axes[1].set_title('Boxplot')
# QQ plot
stats.probplot(data, dist="norm", plot=axes[2])
axes[2].get_lines()[1].set_color('r')
axes[2].set_title('QQ Plot')
# Distplot
sns.histplot(data, kde=True, ax=axes[3])
axes[3].set_title('Distplot')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.countplot(x='Fuel Type', data=df, palette='viridis')
# Out:
# <Axes: xlabel='Fuel Type', ylabel='count'>

# %%
sns.countplot(x='Transmission', data=df, palette='viridis')
# Out:
# <Axes: xlabel='Transmission', ylabel='count'>

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\lenovo\anaconda3\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'Grey'')
#   warnings.warn(
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# ...

# %%
sns.scatterplot(x=df['Kilometer'],y=df['Price'],hue=df['Fuel Tank Capacity'],size=df['Seating Capacity'])
# Out:
# <Axes: xlabel='Kilometer', ylabel='Price'>

# %%
numerical_df = df.select_dtypes(include='number')
numerical_df.corr()['Price']
# Out:
# Price                 1.000000
# Year                  0.311400
# Kilometer            -0.150825
# Length                0.556741
# Width                 0.563996
# Height                0.075080
# Seating Capacity     -0.038524
# Fuel Tank Capacity    0.584631
# Name: Price, dtype: float64

# %%
sns.pairplot(df,hue='Price')
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.countplot(x='Model', data=df, palette='viridis')
# Out:
# <Axes: xlabel='Model', ylabel='count'>

# %%
df.groupby('Make').sum()
# Out:
#                                                            Model      Price  \
# Make
# Audi           A4 2.0 TDI (177bhp) Premium PlusA4 2.0 TDI (14...  343297998
# BMW            X1 xDrive20d M SportX3 xDrive 20d Luxury Line ...  456044998
# Chevrolet      Cruze LTZ ATCruze LTZCaptiva LTZ AWD ATCruze L...    2388999
# Datsun         Go DRedigo S 1.0 AMT [2018-2019]Go T (O)Redigo...    2383000
# Ferrari                                                  488 GTB   35000000
# Fiat                           Linea Emotion 1.4Punto Active 1.3     610000
# Ford           Ecosport Titanium+ 1.0L EcoBoostFigo Duratorq ...   70781999
# Honda          Amaze 1.2 VX i-VTECBrio V MTWR-V VX MT PetrolC...   98292996
# Hyundai        i10 Magna 1.2 Kappa2Elite i20 Sportz 1.2Creta ...  252418973
# Isuzu                                           MU-X 4x2MU-X 4x2    3891000
# Jaguar         F-Pace PrestigeXE Prestige DieselXF 3.0 V6 Pre...   60599000
# ...

# %%
df=df[['Make','Year','Kilometer','Fuel Type','Transmission','Owner','Engine','Fuel Tank Capacity','Price']]

# %%
df.sample(100)
# Out:
#                Make  Year  Kilometer Fuel Type Transmission   Owner   Engine  \
# 1436          Honda  2020      26497    Petrol       Manual  Second  1497 cc
# 1523           Ford  2019      34000    Diesel    Automatic   First  3198 cc
# 1558         Toyota  2013      97000    Diesel       Manual   First  2982 cc
# 1256  Maruti Suzuki  2019      74000    Petrol       Manual   First  1197 cc
# 445   Mercedes-Benz  2018      20000    Diesel    Automatic   First  2143 cc
# ...             ...   ...        ...       ...          ...     ...      ...
# 1691           Ford  2016      69001    Petrol       Manual   First  1499 cc
# 1993  Maruti Suzuki  2017      50000    Diesel       Manual   First  1248 cc
# 623        Mahindra  2022      18000    Diesel    Automatic   First  2184 cc
# 25    Maruti Suzuki  2013      23086    Petrol       Manual   First  1197 cc
# 971         Hyundai  2016      45000    Petrol       Manual   First  1591 cc
#
#       Fuel Tank Capacity    Price
# ...

# %% [markdown]
# #### DATA CLEANING

# %%
def mark_other(fuel):
    if fuel not in ['Petrol','Diesel']:
        return 'Other'
    return fuel
df['Fuel Type']=df['Fuel Type'].apply(mark_other)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9476\1132506071.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Fuel Type']=df['Fuel Type'].apply(mark_other)

# %%
def mark_other_owner(Owner):
    if Owner not in ['First','Second','Third']:
        return 'Other'
    return Owner
df['Owner']=df['Owner'].apply(mark_other_owner)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9476\2949736658.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Owner']=df['Owner'].apply(mark_other_owner)

# %%
df.sample(10)
# Out:
#                Make  Year  Kilometer Fuel Type Transmission  Owner   Engine  \
# 1582           Audi  2022       4600    Petrol    Automatic  First  1984 cc
# 715        Mahindra  2018      83000    Diesel       Manual  First  1493 cc
# 1719          Honda  2016      18800    Petrol       Manual  First  1199 cc
# 1302  Maruti Suzuki  2014      54000    Petrol       Manual  First   998 cc
# 1499        Hyundai  2015      55660    Petrol       Manual  First  1197 cc
# 1804         Toyota  2013      34000    Petrol       Manual  First  1197 cc
# 1734           Audi  2018      17300    Diesel    Automatic  First  1968 cc
# 1131         Toyota  2019      40900    Petrol    Automatic  First  1496 cc
# 1730         Toyota  2019      42794    Diesel    Automatic  First  2755 cc
# 15    Maruti Suzuki  2016      11471    Petrol    Automatic  First   998 cc
#
#       Fuel Tank Capacity    Price
# 1582                55.0  3450000
# 715                  NaN   850000
# ...

# %%
sns.countplot(x='Fuel Type', data=df, palette='viridis')
# Out:
# <Axes: xlabel='Fuel Type', ylabel='count'>

# %%
sns.countplot(x='Owner', data=df, palette='viridis')
# Out:
# <Axes: xlabel='Owner', ylabel='count'>

# %%
df['Engine']=df['Engine'].str.extract('(\d+)',expand=False)
df['Engine']=pd.to_numeric(df['Engine'],errors='coerce')
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9476\1236690492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Engine']=df['Engine'].str.extract('(\d+)',expand=False)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9476\1236690492.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Engine']=pd.to_numeric(df['Engine'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2059 entries, 0 to 2058
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                2059 non-null   object
#  1   Year                2059 non-null   int64
#  2   Kilometer           2059 non-null   int64
#  3   Fuel Type           2059 non-null   object
#  4   Transmission        2059 non-null   object
#  5   Owner               2059 non-null   object
#  6   Engine              1979 non-null   float64
#  7   Fuel Tank Capacity  1946 non-null   float64
#  8   Price               2059 non-null   int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 144.9+ KB

# %%
data = df['Engine']
# Create the figure and axes
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
# KDE plot
sns.kdeplot(data, ax=axes[0])
axes[0].set_title('KDE Plot')
# Boxplot
sns.boxplot(data, ax=axes[1])
axes[1].set_title('Boxplot')
# QQ plot
stats.probplot(data, dist="norm", plot=axes[2])
axes[2].get_lines()[1].set_color('r')
axes[2].set_title('QQ Plot')
# Distplot
sns.histplot(data, kde=True, ax=axes[3])
axes[3].set_title('Distplot')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df['Make']=df['Make'].str.replace('-',' ')
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9476\1767156063.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Make']=df['Make'].str.replace('-',' ')

# %%
df.sample(10)
# Out:
#                Make  Year  Kilometer Fuel Type Transmission   Owner  Engine  \
# 1236            BMW  2013      65000    Diesel    Automatic  Second  1995.0
# 989   Maruti Suzuki  2013      66000    Petrol       Manual   First  1197.0
# 1041          Skoda  2014      53000    Petrol    Automatic  Second  1798.0
# 94    Mercedes Benz  2018      83400    Diesel    Automatic  Second     NaN
# 912            Ford  2021       9400    Diesel    Automatic   First  1996.0
# 1871            Kia  2020      27000    Diesel       Manual   First  1493.0
# 2043  Mercedes Benz  2016      21200    Diesel    Automatic   First  2143.0
# 1946          Honda  2014      58600    Petrol       Manual   First  1198.0
# 1298            BMW  2017      35000    Diesel    Automatic   First  2993.0
# 681          Jaguar  2019      13500    Diesel    Automatic  Second  1999.0
#
#       Fuel Tank Capacity    Price
# 1236                57.0  1395000
# 989                 42.0   340000
# ...

# %% [markdown]
# # outlier correction and filling missing value

# %%
#year
percentile25=df['Year'].quantile(0.25)
percentile75=df['Year'].quantile(0.75)

# %%
iqr=percentile75-percentile25

# %%
upper_limit=percentile75+1.5*iqr
lower_limit=percentile75-1.5*iqr

# %%
print("Upper limit",upper_limit)
print("Lower limit",lower_limit)
# Out:
# Upper limit 2026.5
# Lower limit 2011.5

# %%
df[df['Year']<lower_limit]
# Out:
#                Make  Year  Kilometer Fuel Type Transmission   Owner  Engine  \
# 2           Hyundai  2011      67000    Petrol       Manual   First  1197.0
# 34          Hyundai  2009      72000     Other       Manual  Second  1086.0
# 43    Mercedes Benz  2010      34105    Petrol    Automatic   First  1796.0
# 68            Honda  2006     130000    Petrol       Manual   Third  1799.0
# 80    Mercedes Benz  2011      51500    Diesel    Automatic  Second  2143.0
# ...             ...   ...        ...       ...          ...     ...     ...
# 2031  Maruti Suzuki  2008      65000    Diesel       Manual  Second  1248.0
# 2033  Mercedes Benz  2011      65000    Petrol    Automatic  Second  1991.0
# 2034  Maruti Suzuki  2011      65000    Diesel       Manual   First  1248.0
# 2035  Maruti Suzuki  2011      41000    Petrol       Manual  Second   998.0
# 2036         Toyota  2010     127000    Diesel       Manual   Third  2982.0
#
#       Fuel Tank Capacity    Price
# ...

# %%
new_df = df.copy()

new_df['Year'] = np.where(
    new_df['Year'] > upper_limit,
    upper_limit,
    np.where(
        new_df['Year'] < lower_limit,
        lower_limit,
        new_df['Year']
    )
)

# %%
new_df.shape
# Out:
# (2059, 9)

# %%
data = new_df['Year']
# Create the figure and axes
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
# KDE plot
sns.kdeplot(data, ax=axes[0])
axes[0].set_title('KDE Plot')
# Boxplot
sns.boxplot(data, ax=axes[1])
axes[1].set_title('Boxplot')
# QQ plot
stats.probplot(data, dist="norm", plot=axes[2])
axes[2].get_lines()[1].set_color('r')
axes[2].set_title('QQ Plot')
# Distplot
sns.histplot(data, kde=True, ax=axes[3])
axes[3].set_title('Distplot')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Kilometer
percentile25=new_df['Kilometer'].quantile(0.25)
percentile75=new_df['Kilometer'].quantile(0.75)

# %%
iqr=percentile75-percentile25

# %%
upper_limit=percentile25+1.5*iqr
lower_limit=percentile75-1.5*iqr

# %%
print("Upper limit", upper_limit)
print("Lower limit", lower_limit)
# Out:
# Upper limit 93500.0
# Lower limit 7500.0

# %%
new_df[new_df['Kilometer']<lower_limit]
# Out:
#                Make    Year  Kilometer Fuel Type Transmission  Owner  Engine  \
# 16    Maruti Suzuki  2019.0       3583    Petrol       Manual  First   796.0
# 20    Maruti Suzuki  2020.0       2169    Petrol    Automatic  First   998.0
# 95          Porsche  2022.0       2766    Petrol    Automatic  First  2995.0
# 139            Audi  2022.0          1    Petrol    Automatic  Other  1984.0
# 156      Land Rover  2020.0       6000    Diesel    Automatic  First  1999.0
# ...             ...     ...        ...       ...          ...    ...     ...
# 1977  Mercedes Benz  2022.0       5500    Diesel    Automatic  Other  1950.0
# 2000           Jeep  2022.0       2000    Petrol    Automatic  First  1368.0
# 2020        Hyundai  2022.0       5800    Diesel    Automatic  First  1493.0
# 2022            Kia  2021.0       7000    Petrol    Automatic  First  1353.0
# 2044       Mahindra  2022.0         75    Petrol    Automatic  First  1997.0
#
#       Fuel Tank Capacity     Price
# ...

# %%
new_df['Kilometer']=np.where(
    new_df['Kilometer']>upper_limit,
    upper_limit,
    np.where(new_df['Kilometer']<lower_limit,
            lower_limit,
            new_df['Kilometer'])
)

# %%
data = new_df['Kilometer']
# Create the figure and axes
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
# KDE plot
sns.kdeplot(data, ax=axes[0])
axes[0].set_title('KDE Plot')
# Boxplot
sns.boxplot(data, ax=axes[1])
axes[1].set_title('Boxplot')
# QQ plot
stats.probplot(data, dist="norm", plot=axes[2])
axes[2].get_lines()[1].set_color('r')
axes[2].set_title('QQ Plot')
# Distplot
sns.histplot(data, kde=True, ax=axes[3])
axes[3].set_title('Distplot')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#egine
data = df['Engine']
# Create the figure and axes
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
# KDE plot
sns.kdeplot(data, ax=axes[0])
axes[0].set_title('KDE Plot')
# Boxplot
sns.boxplot(data, ax=axes[1])
axes[1].set_title('Boxplot')
# QQ plot
stats.probplot(data, dist="norm", plot=axes[2])
axes[2].get_lines()[1].set_color('r')
axes[2].set_title('QQ Plot')
# Distplot
sns.histplot(data, kde=True, ax=axes[3])
axes[3].set_title('Distplot')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
new_df['Engine']=new_df['Engine'].fillna(new_df['Engine'].mean())

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
df['Engine'].plot(kind='kde', ax=ax)

# variable imputed with the median
new_df['Engine'].plot(kind='kde', ax=ax, color='red')


# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend('with_missing', 'fillna=mean', loc='best')
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9476\3118434884.py:13: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/users/explain/axes/legend_guide.html#controlling-the-legend-entries
#   ax.legend('with_missing', 'fillna=mean', loc='best')

# %%
percentile25=new_df['Engine'].quantile(0.25)
percentile75=new_df['Engine'].quantile(0.75)

# %%
iqr=percentile75-percentile25

# %%
upper_limit=percentile25+1.5*iqr
lower_limit=percentile75-1.5*iqr

# %%
print("Upper limit", upper_limit)
print("Lower limit", lower_limit)
# Out:
# Upper limit 2393.5
# Lower limit 799.5

# %%
new_df['Engine']=np.where(
    new_df['Engine']>upper_limit,
    upper_limit,
    np.where(new_df['Engine']<lower_limit,
            lower_limit,
            new_df['Engine'])
)

# %%
#egine
data = new_df['Engine']
# Create the figure and axes
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
# KDE plot
sns.kdeplot(data, ax=axes[0])
axes[0].set_title('KDE Plot')
# Boxplot
sns.boxplot(data, ax=axes[1])
axes[1].set_title('Boxplot')
# QQ plot
stats.probplot(data, dist="norm", plot=axes[2])
axes[2].get_lines()[1].set_color('r')
axes[2].set_title('QQ Plot')
# Distplot
sns.histplot(data, kde=True, ax=axes[3])
axes[3].set_title('Distplot')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Fuel Tank Capacity
data = df['Fuel Tank Capacity']
# Create the figure and axes
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
# KDE plot
sns.kdeplot(data, ax=axes[0])
axes[0].set_title('KDE Plot')
# Boxplot
sns.boxplot(data, ax=axes[1])
axes[1].set_title('Boxplot')
# QQ plot
stats.probplot(data, dist="norm", plot=axes[2])
axes[2].get_lines()[1].set_color('r')
axes[2].set_title('QQ Plot')
# Distplot
sns.histplot(data, kde=True, ax=axes[3])
axes[3].set_title('Distplot')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
new_df['Fuel Tank Capacity']=new_df['Fuel Tank Capacity'].fillna(new_df['Fuel Tank Capacity'].mean())

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# original variable distribution
df['Fuel Tank Capacity'].plot(kind='kde', ax=ax)

# variable imputed with the median
new_df['Fuel Tank Capacity'].plot(kind='kde', ax=ax, color='red')


# add legends
lines, labels = ax.get_legend_handles_labels()
ax.legend('with_missing', 'fillna=mean', loc='best')
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9476\2093613863.py:13: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/users/explain/axes/legend_guide.html#controlling-the-legend-entries
#   ax.legend('with_missing', 'fillna=mean', loc='best')

# %%
new_df['Fuel Tank Capacity'].skew()
# Out:
# 0.8773825096816811

# %%
percentile25=new_df['Fuel Tank Capacity'].quantile(0.25)
percentile75=new_df['Fuel Tank Capacity'].quantile(0.75)

# %%
iqr=percentile75-percentile25

# %%
upper_limit=percentile25+1.5*iqr
lower_limit=percentile75-1.5*iqr

# %%
print("Upper limit", upper_limit)
print("Lower limit", lower_limit)
# Out:
# Upper limit 69.0
# Lower limit 33.0

# %%
new_df['Fuel Tank Capacity']=np.where(
    new_df['Fuel Tank Capacity']>upper_limit,
    upper_limit,
    np.where(new_df['Fuel Tank Capacity']<lower_limit,
            lower_limit,
            new_df['Fuel Tank Capacity'])
)

# %%
data = new_df['Fuel Tank Capacity']
# Create the figure and axes
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
# KDE plot
sns.kdeplot(data, ax=axes[0])
axes[0].set_title('KDE Plot')
# Boxplot
sns.boxplot(data, ax=axes[1])
axes[1].set_title('Boxplot')
# QQ plot
stats.probplot(data, dist="norm", plot=axes[2])
axes[2].get_lines()[1].set_color('r')
axes[2].set_title('QQ Plot')
# Distplot
sns.histplot(data, kde=True, ax=axes[3])
axes[3].set_title('Distplot')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(new_df)
prof.to_file(output_file='output_new.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\lenovo\anaconda3\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'Petrol'')
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
new_df=new_df.drop_duplicates()

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(new_df)
prof.to_file(output_file='output_final.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\lenovo\anaconda3\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'Petrol'')
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
data = new_df['Price']
# Create the figure and axes
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
# KDE plot
sns.kdeplot(data, ax=axes[0])
axes[0].set_title('KDE Plot')
# Boxplot
sns.boxplot(data, ax=axes[1])
axes[1].set_title('Boxplot')
# QQ plot
stats.probplot(data, dist="norm", plot=axes[2])
axes[2].get_lines()[1].set_color('r')
axes[2].set_title('QQ Plot')
# Distplot
sns.histplot(data, kde=True, ax=axes[3])
axes[3].set_title('Distplot')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
data = new_df['Price']
# Create the figure and axes
fig, axes = plt.subplots(1, 4, figsize=(24, 6))
# KDE plot
sns.kdeplot(data, ax=axes[0])
axes[0].set_title('KDE Plot')
# Boxplot
sns.boxplot(data, ax=axes[1])
axes[1].set_title('Boxplot')
# QQ plot
.probplot(data, dist="norm", plot=axes[2])
axes[2].get_lines()[1].set_color('r')
axes[2].set_title('QQ Plot')
# Distplot
sns.histplot(data, kde=True, ax=axes[3])
axes[3].set_title('Distplot')
plt.tight_layout()
plt.show()
# Out:
#   Cell In[75], line 11
#     .probplot(data, dist="norm", plot=axes[2])
#     ^
# SyntaxError: invalid syntax

# %%
new_df['Price']=df['Price']

# %% [markdown]
# # model traing

# %%
from sklearn.model_selection import train_test_split
x=new_df.drop(columns=['Price'])
y=new_df['Price']
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
X_train.shape,y_train.shape
# Out:
# ((1640, 8), (1640,))

# %%
#import
from sklearn.compose import ColumnTransformer 
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import FunctionTransformer
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.impute import KNNImputer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV,cross_val_score
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,BaggingRegressor,ExtraTreesRegressor,GradientBoostingRegressor
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder,LabelEncoder,StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression,ridge_regression,SGDRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

# %%
X_train.sample(10)
# Out:
#                Make    Year  Kilometer Fuel Type Transmission   Owner  Engine  \
# 1476  Maruti Suzuki  2018.0    50000.0    Petrol       Manual   First  1197.0
# 1688           Audi  2016.0    84878.0    Diesel    Automatic  Second  1968.0
# 1712         Toyota  2018.0    51000.0    Diesel    Automatic   First  2393.5
# 1666     Volkswagen  2017.0    55000.0    Petrol       Manual   First  1198.0
# 1609        Hyundai  2017.0    80000.0    Diesel    Automatic   First  1582.0
# 1320     Volkswagen  2013.0    53000.0    Petrol       Manual  Second  1198.0
# 967         Hyundai  2019.0    34400.0    Petrol    Automatic   First  1086.0
# 694           Honda  2014.0    31000.0    Petrol       Manual   First  1198.0
# 669         Hyundai  2018.0    45915.0    Diesel    Automatic   First  1582.0
# 63    Maruti Suzuki  2021.0    24000.0    Petrol       Manual   First  1462.0
#
#       Fuel Tank Capacity
# 1476                42.0
# 1688                64.0
# 1712                69.0
# ...

# %%
num_col=['Year','Kilometer','Engine','Fuel Tank Capacity']
cat_col=['Make','Transmission','Fuel Type','Owner']

# %%
preprocessor=ColumnTransformer(transformers=[
    ('Ordinal',OneHotEncoder(handle_unknown='ignore',sparse=False,drop='first'),cat_col,),
    ('standardScaler',StandardScaler(),num_col,)
    
],remainder='passthrough')

# %%
tf_X_train=preprocessor.fit_transform(X_train)
tf_X_test=preprocessor.transform(X_test)
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
models=[RandomForestRegressor(),
        AdaBoostRegressor(),BaggingRegressor(),ExtraTreesRegressor(),GradientBoostingRegressor(),LinearRegression(),SGDRegressor(),SVR(),DecisionTreeRegressor()]

# %%
import time
Name=[]
r2=[]
Time_Taken=[]
for model in models:
    Name.append(type(model).__name__)
    begin=time.time()
    model.fit(tf_X_train,y_train)
    y_pred=model.predict(tf_X_test)
    end=time.time()
    score=r2_score(y_test,y_pred)
    r2.append(score)
    Time_Taken.append(end-begin)

# %%
data={'model':Name,
     'r2_score':r2,
     'time_':Time_Taken
     }
all_model=pd.DataFrame(data)

# %%
all_model
# Out:
#                        model  r2_score     time_
# 0      RandomForestRegressor  0.850892  0.619094
# 1          AdaBoostRegressor  0.383195  0.122600
# 2           BaggingRegressor  0.846600  0.065597
# 3        ExtraTreesRegressor  0.850511  0.537033
# 4  GradientBoostingRegressor  0.876951  0.178534
# 5           LinearRegression  0.603897  0.015533
# 6               SGDRegressor  0.601325  0.214083
# 7                        SVR -0.138886  0.212177
# 8      DecisionTreeRegressor  0.832727  0.007007

# %%
param_grid={
    'n_estimators':[50,100,200],
     'max_depth':[None,10,20,30],
'min_samples_leaf':[1,2,5],
'max_features':[None,'log2','sqrt'],
'max_leaf_nodes':[None,2,5,10,20],
  'n_jobs':[-1]
}

# %%
rfr=RandomForestRegressor(max_depth=30,n_jobs=-1, n_estimators=200,min_samples_leaf=1)
rfr.fit(tf_X_train,y_train)
y_pred=rfr.predict(tf_X_test)

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.8563851067111186

# %%
grid_search=GridSearchCV(estimator=rfr,param_grid=param_grid,cv=5,n_jobs=-1,verbose=2)

# %%
grid_search.fit(tf_X_train,y_train)
# Out:
# Fitting 5 folds for each of 540 candidates, totalling 2700 fits
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'max_features': [None, 'log2', 'sqrt'],
#                          'max_leaf_nodes': [None, 2, 5, 10, 20],
#                          'min_samples_leaf': [1, 2, 5],
#                          'n_estimators': [50, 100, 200], 'n_jobs': [-1]},
#              verbose=2)

# %%
grid_search.best_params_
# Out:
# {'max_depth': 30,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_samples_leaf': 1,
#  'n_estimators': 200,
#  'n_jobs': -1}

# %%
grid_search.best_score_
# Out:
# 0.7753085036282787

# %%
X_train.sample()
# Out:
#        Make    Year  Kilometer Fuel Type Transmission   Owner  Engine  \
# 238  Toyota  2011.5    93500.0    Diesel       Manual  Second  2393.5
#
#      Fuel Tank Capacity
# 238                69.0

# %% [markdown]
# # deployment model

# %%
trf1=ColumnTransformer([('one_hot_fuel_type',OneHotEncoder(sparse=False,drop='first',handle_unknown='ignore'),[0,3,4,5])],remainder='passthrough')

# %%
trf2=ColumnTransformer([('standar_scaler_all',StandardScaler(),[1,2,6,7])],remainder='passthrough')

# %%
trf3=RandomForestRegressor()

# %%
pipe = make_pipeline(trf1,trf2,trf3)

# %%
pipe.fit(X_train, y_train)
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Pipeline(steps=[('columntransformer-1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('one_hot_fuel_type',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   [0, 3, 4, 5])])),
#                 ('columntransformer-2',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('standar_scaler_all',
# ...

# %%
predictions = pipe.predict(X_test)

# %%
score = pipe.score(X_test, y_test)
score
# Out:
# 0.8436775211235539

# %%
from sklearn.metrics import r2_score
r2_score(y_test,predictions)
# Out:
# 0.8436775211235539

# %%
cross_val_score(pipe,X_train,y_train,cv=10).mean()
# Out:
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# C:\Users\lenovo\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# ...
